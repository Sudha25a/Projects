# %%
#importing pandas as pd
import pandas as pd

# %%
df = pd.read_csv('./movies_2.csv')
df
# Out:
#      MovieID                                  Title MPAA Rating       Budget  \
# 0          1                     Look Who's Talking       PG-13    7500000.0
# 1          2                     Driving Miss Daisy          PG    7500000.0
# 2          3                         Turner & Hooch          PG   13000000.0
# 3          4             Born on the Fourth of July           R   14000000.0
# 4          5                        Field of Dreams          PG   15000000.0
# ..       ...                                    ...         ...          ...
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
# 615        0                                    NaN         NaN          NaN
#
# ...

# %%
#the number of rows and columns present in the data set (i.e. the shape of the dataframe)
df.shape
# Out:
# (616, 11)

# %%
#columns present in the data set, along with the data type (use info or dtypes method)
df.info
# Out:
# <bound method DataFrame.info of      MovieID                                  Title MPAA Rating       Budget  \
# 0          1                     Look Who's Talking       PG-13    7500000.0
# 1          2                     Driving Miss Daisy          PG    7500000.0
# 2          3                         Turner & Hooch          PG   13000000.0
# 3          4             Born on the Fourth of July           R   14000000.0
# 4          5                        Field of Dreams          PG   15000000.0
# ..       ...                                    ...         ...          ...
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
# 615        0                                    NaN         NaN          NaN
#
# ...

# %%
#check how many NaN we have for MPAA Rating, Budget, Gross, Release Date, Genre, Runtime, 
# Rating and Rating Count columns
df.isnull().sum()
# Out:
# MovieID           0
# Title             1
# MPAA Rating       1
# Budget            1
# Gross             1
# Release Date      1
# Genre             1
# Runtime           1
# Rating          108
# Rating Count    108
# Summary         120
# dtype: int64

# %%
# Get rid of the Summary column (use the drop() method)
new_df = movies.drop('Summary', axis='columns') # (column = 1, row = 0)
new_df
# Out:
#      MovieID                                Title MPAA Rating       Budget  \
# 0          1                   Look Who's Talking       PG-13    7500000.0
# 1          2                   Driving Miss Daisy          PG    7500000.0
# 2          3                       Turner & Hooch          PG   13000000.0
# 3          4           Born on the Fourth of July           R   14000000.0
# 4          5                      Field of Dreams          PG   15000000.0
# ..       ...                                  ...         ...          ...
# 491      506                           Big Hero 6          PG  165000000.0
# 492      507                         Interstellar       PG-13  165000000.0
# 493      508  Captain America: The Winter Soldier       PG-13  170000000.0
# 494      509       Dawn of the Planet of the Apes       PG-13  170000000.0
# 495      510              Guardians of the Galaxy       PG-13  170000000.0
#
# ...

# %%
# use the rename method to change all columns names to lowercase, 
# and replace spaces with underscores if the name is made of more than one word
renamed = movies.rename(columns={ "MovieID": "movies", "Gross": "Profit"})
renamed.to_csv("output.csv")
renamed
# Out:
#      movies                       Title MPAA Rating       Budget  \
# 15       16          The Little Mermaid          PG   40000000.0
# 46       47        Beauty and the Beast          PG   25000000.0
# 188     189         The Prince of Egypt          PG   70000000.0
# 215     216                      Tarzan          PG  150000000.0
# 241     242                       Shrek          PG   60000000.0
# 261     262                     Ice Age          PG   59000000.0
# 304     305             The Incredibles          PG   92000000.0
# 311     312                     Shrek 2          PG  150000000.0
# 382     386               Kung Fu Panda          PG  130000000.0
# 404     412                          Up          PG  175000000.0
# 412     421               Despicable Me          PG   69000000.0
# 417     426                    Megamind          PG  130000000.0
# 420     429    How to Train Your Dragon          PG  165000000.0
# ...

# %%
# Get rid of the last row, the one containing NaN for each column (use drop() method and row index)
# movies.dropna(inplace=True)
# movies



# movies.reset_index(inplace=True, drop=True)
movies
# Out:
#     MovieID                       Title MPAA Rating       Budget  \
# 0        16          The Little Mermaid          PG   40000000.0
# 1        47        Beauty and the Beast          PG   25000000.0
# 2       189         The Prince of Egypt          PG   70000000.0
# 3       216                      Tarzan          PG  150000000.0
# 4       242                       Shrek          PG   60000000.0
# 5       262                     Ice Age          PG   59000000.0
# 6       305             The Incredibles          PG   92000000.0
# 7       312                     Shrek 2          PG  150000000.0
# 8       386               Kung Fu Panda          PG  130000000.0
# 9       412                          Up          PG  175000000.0
# 10      421               Despicable Me          PG   69000000.0
# 11      426                    Megamind          PG  130000000.0
# 12      429    How to Train Your Dragon          PG  165000000.0
# ...

# %%
df[['Gross', 'Budget']].mean()
# Out:
# Gross     4.453221e+08
# Budget    9.491710e+07
# dtype: float64

# %%
# use the fillna() method to replace the missing values of Rating with their median
df.fillna(df["Rating"].median())
# Out:
#      MovieID                                  Title MPAA Rating       Budget  \
# 0          1                     Look Who's Talking       PG-13    7500000.0
# 1          2                     Driving Miss Daisy          PG    7500000.0
# 2          3                         Turner & Hooch          PG   13000000.0
# 3          4             Born on the Fourth of July           R   14000000.0
# 4          5                        Field of Dreams          PG   15000000.0
# ..       ...                                    ...         ...          ...
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
# 615        0                                    6.9         6.9          6.9
#
# ...

# %%
pd.options.display.max_info_columns
# Out:
# 100

# %%
# Drop the duplicates, if any
df.drop_duplicates()
# Out:
#      MovieID                                  Title MPAA Rating       Budget  \
# 0          1                     Look Who's Talking       PG-13    7500000.0
# 1          2                     Driving Miss Daisy          PG    7500000.0
# 2          3                         Turner & Hooch          PG   13000000.0
# 3          4             Born on the Fourth of July           R   14000000.0
# 4          5                        Field of Dreams          PG   15000000.0
# ..       ...                                    ...         ...          ...
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
# 615        0                                    NaN         NaN          NaN
#
# ...

# %%
# importing pandas as pd
import pandas as pd
 
# Making data frame from the csv file
df = pd.read_csv("movies_2.csv")
df[:10]
# Out:
#    MovieID                       Title MPAA Rating      Budget        Gross  \
# 0        1          Look Who's Talking       PG-13   7500000.0  296000000.0
# 1        2          Driving Miss Daisy          PG   7500000.0  145793296.0
# 2        3              Turner & Hooch          PG  13000000.0   71079915.0
# 3        4  Born on the Fourth of July           R  14000000.0  161001698.0
# 4        5             Field of Dreams          PG  15000000.0   84431625.0
# 5        6                  Uncle Buck          PG  15000000.0   79258538.0
# 6        7     When Harry Met Sally...           R  16000000.0   92800000.0
# 7        8          Dead Poets Society          PG  16400000.0  235860116.0
# 8        9                  Parenthood       PG-13  20000000.0  126297830.0
# 9       10             Lethal Weapon 2           R  25000000.0  227853986.0
#
#   Release Date    Genre  Runtime  Rating  Rating Count  \
# 0   1989-10-12  Romance     93.0     5.9       73638.0
# ...

# %%
# Convert Budget into integer type (use the astype() method)
df = df.astype("Budget",int) 
# df = df.astype ['Budget':integer]
# df('Budget') = df('Budget').astype('int')
df ['Budget']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[173], line 2
#       1 # Convert Budget into integer type (use the astype() method)
# ----> 2 df = df.astype("Budget",int)
#       3 # df = df.astype ['Budget':integer]
#       4 # df('Budget') = df('Budget').astype('int')
#       5 df ['Budget']
#
# File c:\Users\meeta\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# ...

# %%
# Convert Gross into integer type
# df = df.astype(dtype, 'Gross':'int')
# df('Gross') = df('Gross').astype('int')

# %%
# Convert Release Date into date type (use the to_datetime method)

# %% [markdown]
# show the movies with more than 7 in Rating & greater than 50 million Gross

# %%
#if [df["Rating"] > 7 and movie["Gross"] > 50]

# %%
from datetime import datetime
# date 

# release_date_str = '2022-07-25'  # example release date string

# release_date = datetime.strptime(release_date_str, '%Y-%m-%d')

# release_date is now a datetime object
# print(type(release_date))  # Output: <class 'datetime.datetime'>

# %% [markdown]
# show the movies with more than 7 in Rating & greater than 50 million Gross & with Parental guidance as MPAA Rating

# %%
# movies in Rating > 7, Gross > 50 million, and MPAA Rating = 'PG'
movies = movies[(movies['Rating'] > 7) & (movies['Gross'] >  50000000) & (movies['MPAA Rating'] == 'PG')]
print(movies)
# Out:
#      MovieID                       Title MPAA Rating       Budget  \
# 15        16          The Little Mermaid          PG   40000000.0
# 46        47        Beauty and the Beast          PG   25000000.0
# 188      189         The Prince of Egypt          PG   70000000.0
# 215      216                      Tarzan          PG  150000000.0
# 241      242                       Shrek          PG   60000000.0
# 261      262                     Ice Age          PG   59000000.0
# 304      305             The Incredibles          PG   92000000.0
# 311      312                     Shrek 2          PG  150000000.0
# 382      386               Kung Fu Panda          PG  130000000.0
# 404      412                          Up          PG  175000000.0
# 412      421               Despicable Me          PG   69000000.0
# 417      426                    Megamind          PG  130000000.0
# 420      429    How to Train Your Dragon          PG  165000000.0
# ...

# %% [markdown]
# show the count of Animation movies with more than 7 in Rating (use the shape() method)

# %%
import pandas as pd
import numpy as np

movies = movies[movies['Genre'] == 'Animation']  # filter for animation movies

# movies['Rating'] = pd.to_numeric(Animation_movies['rating'])

# count_high_rated_animation = len(animation_movies[animation_movies['rating'] > 7])

# print(f"Number of animation movies with ratings > 7: {count_high_rated_animation}")

# %% [markdown]
# show the top 5 movies based on Budget

# %%
import pandas as pd
import numpy as np
movies_df = pd.read_csv('movies_2.csv')
movies_df
# movies_df = movies_df[movies_df['Budget'].notna()].sort_values(by='Budget', ascending=False)
top_5_movies = movies_df.head(5)
print(top_5_movies[['MovieID', 'Budget']])
# Out:
#    MovieID      Budget
# 0        1   7500000.0
# 1        2   7500000.0
# 2        3  13000000.0
# 3        4  14000000.0
# 4        5  15000000.0

# %%
# show the top 5 movies based on Budget
df.sort_values("Budget", ascending=False).head(5)
# Out:
#      MovieID                                        Title MPAA Rating  \
# 594      595                       Avengers: Infinity War       PG-13
# 454      455  Pirates of the Caribbean: On Stranger Tides       PG-13
# 614      615                            Avengers: Endgame       PG-13
# 574      575                     Star Wars: The Last Jedi       PG-13
# 375      376     Pirates of the Caribbean: At World's End       PG-13
#
#           Budget         Gross Release Date            Genre  Runtime  Rating  \
# 594  400000000.0  2.048000e+09   2018-04-23           Action    149.0     NaN
# 454  380000000.0  1.045714e+09   2011-05-14           Action    136.0     6.6
# 614  356000000.0  2.796000e+09   2019-04-22           Action    181.0     NaN
# 574  317000000.0  1.333000e+09   2019-12-09  Science Fiction    152.0     NaN
# 375  300000000.0  9.610000e+08   2007-05-19        Adventure    169.0     7.1
#
#      Rating Count                                            Summary
# ...

# %%
# show the top 5 Comedy movies by Rating

df[df['Genre'] == "Comedy"]
df[df['Genre'] == "Comedy"].sort_values("Rating", ascending=False).head(5)
# Out:
#      MovieID                   Title MPAA Rating       Budget        Gross  \
# 111      112            Forrest Gump       PG-13   55000000.0  677945399.0
# 185      186         The Truman Show          PG   60000000.0  264118201.0
# 80        81           Groundhog Day          PG   14600000.0   70906973.0
# 254      255          Monsters, Inc.           G  115000000.0  562816256.0
# 316      317  The 40 Year Old Virgin           R   26000000.0  109449237.0
#
#     Release Date   Genre  Runtime  Rating  Rating Count  \
# 111   1994-07-06  Comedy    142.0     8.8     1657851.0
# 185   1998-06-04  Comedy    103.0     8.1      859224.0
# 80    1993-02-11  Comedy    101.0     8.0      549538.0
# 254   2001-11-01  Comedy     92.0     8.0      758349.0
# 316   2005-08-11  Comedy    116.0     7.7      500448.0
#
#                                                Summary
# 111  The presidencies of Kennedy and Johnson, the e...
# 185  An insurance salesman discovers his whole life...
# ...

# %%
# top 5 movie names by Rating

df.sort_values("Rating", ascending=False).head(5)
# Out:
#      MovieID                                          Title MPAA Rating  \
# 393      394                                The Dark Knight       PG-13
# 98        99                              Jurassic Park III       PG-13
# 287      288  The Lord of the Rings: The Return of the King       PG-13
# 99       100                                   Pulp Fiction           R
# 83        84                               Schindler's List           R
#
#           Budget         Gross Release Date     Genre  Runtime  Rating  \
# 393  185000000.0  1.004558e+09   2008-07-16    Action    152.0     9.0
# 98    93000000.0  3.688000e+08   2001-07-16  Thriller     92.0     8.9
# 287   94000000.0  1.118889e+09   2003-12-01   Fantasy    201.0     8.9
# 99     8000000.0  2.139288e+08   1994-09-10  Thriller    154.0     8.9
# 83    22000000.0  3.213656e+08   1993-11-29   History    195.0     8.9
#
#      Rating Count                                            Summary
# ...

# %%
# top 3 high Gross Romance movies released after 1999 (typecast it to datetime)

from datetime import datetime
df[(df['Genre'] == "Romance") & (df["Release_Date"] > datetime.time("1999-12-31", "%Y-%m-%d"))].sort_values("Gross", ascending=False).head(3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\meeta\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ReleaseDate'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[158], line 4
# ...

# %%
# how many Genres are present in the dataframe? (use value_counts() method which applies to Series, not Dataframe)
Genre_series = df['Genre'].explode()
Genre_series.value_counts()
# Out:
# Genre
# Action             110
# Comedy              99
# Animation           87
# Drama               66
# Thriller            41
# Science Fiction     37
# Adventure           30
# Family              29
# Romance             28
# Fantasy             27
# Crime               17
# Horror              14
# Mystery             11
# War                  9
# Western              6
# History              4
# Name: count, dtype: int64

# %%
# top 5 most expensive movies released after 1999 (measured by Budget)
df[df["Release_Date"] > datetime.strptime("1999-12-31", "%Y-%m-%d")].sort_values("Budget", ascending=False).head(3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\meeta\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Release_Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[161], line 2
# ...
